# %%
# hunted mansion text adveture game by Isabella Ricci 


#defining the premise of the game with a doc string. to read call help on doc string

def intro():
    """The premise for this game is an adventure inside a haunted mansion
    based on Disney's Hunted Mansion. The user will begin their journey 
    on the outside of the mansion and make his way in and go through up to 3 doors. 
    the game can be won or lost in a very short amount of time but can take longer if the user 
    enters and exits trough more than one door. 
    The main unresolved bug is that every time you lose or input a wrong answer it will 
    take you to the last checkpoint and not the last decision, since there are only 5 
    defined scenes. Also sometimes the input comes above the text, regardless that it is 
    in the correct order."""

    
    outside()
    
#this is the default fail funcition  (not a scene)

def  fail():
    looser=input(prompt="""you have failed, do you want to try again? 
    1.yes
    2.no
    \n""")
    if "yes" in looser: #defining if player whants to try again with an if function 
        outside()
    elif "no" in looser:
        print ("""okay bye""")
    elif float(looser)==1:
        outside()
    elif float(looser)==2:
        print ("""okay bye""")   

        
# room 1 outside mansion               

def outside(): #stage No.1 user beguins game here 
    des_1 = input (prompt = """you stand ouside of the mansion, 
    chills running down your spine.
    you wander, what to do next?
    1. knock on the very creepy door.
    2. you try doorknob.
    3. you turn arround and leave.
    (answer 1, 2 or 3)
    \n """)
    print ("*****************************************")
        
    if "knock" in des_1:#this is the first decision in door
        des_2 = input(prompt = """the door opens, apparently on its own, what shall you do next? 
        1. go in
        2. turn arround
        (answer 1 or 2)\n""")
        print ("""*******************************""")
        
        try:
            if float(des_2) == 1:
                print ("""You slowly make your way into the house.""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
            elif float(des_2)== 2:
                print (""" just as you are leavin, you notice...someone inside
                is calling your name!!! 
                you are too intrigued, you have to go in""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
            else:
                print ("""unexpected input, try again""")
                input(prompt= '<Press enter key to continue>\n')
                outside()
            
        except:
    
            if "go"  in des_2:#this is the decision to knock on door 
                print ("""You slowly make your way into the house.""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
            elif "turn" in des_2:
                print (""" just as you are leavin, you notice ...someone inside 
                is calling your name!!! 
                you are too intrigued, you have to go in""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
       
            else:
                print ("""unexpected input, try again""")
                input(prompt= '<Press enter key to continue>\n')
                outside()

    elif "doorknob"in des_1: #decision to try the doorknoob
        print ("""oh no! Its locked. start over""") 
        input(prompt= '<Press enter key to continue>\n')
        print("************************************")
        outside()

    elif "try" in des_1: #decision to try the doorknoob
        print ("""oh no! Its locked. start over""")
        input(prompt= '<Press enter key to continue>\n')
        outside()
    
    elif "turn" in des_1:
        print (""" just as you are leavin, you notice the door opens on its
            own, and...someone is calling your name!!! 
            you are too intrigued, you have to go in""")
        print ("\n")
        print ("""Welcome to the mansion""")
        input(prompt= '<Press enter key to continue>\n')
        in_house()
    
    elif des_1=="1": 
        des_2 = input(prompt = """the door opens, what shall you do next? 
        1. go in
        2. turn arround
        (answer 1 or 2)""")
        print ("***********************************")
    
        try:
            if float(des_2) == 1:
                print ("""You slowly make your way into the house.""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
            elif float(des_2)== 2:
                print (""" just as you are leavin, you notice...someone is calling your name!!! 
                you are too intrigued, you have to go in""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
            else:
                print ("""unexpected input, try again""")
                input(prompt= '<Press enter key to continue>\n')
                outside()
            
        except:
    
            if "go"  in des_2:#this is the decision to knock on door 
                print ("""You slowly make your way into the house.""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
            elif "turn" in des_2:
                print (""" just as you are leavin, you notice...someone is calling your name!!! 
                you are to intrigued, you have to go in.""")
                input(prompt= '<Press enter key to continue>\n')
                print ("""Welcome to the mansion.""")
                input(prompt= '<Press enter key to continue>\n')
                in_house()
       
            else:
                print ("""unexpected input, try again""")
                input(prompt= '<Press enter key to continue>\n')
                outside()
        
    elif des_1== "2":
        print ("""oh no! Its locked. start over.""")
        input(prompt= '<Press enter key to continue>\n')
        outside()

    elif des_1== "3":
        
        print (""" just as you are leavin, you notice...someone is calling your name!!! 
            you are too intrigued, you have to go in\n""")
        print ("""Welcome to the mansion""")
        input(prompt= '<Press enter key to continue>\n')
    
        in_house()
        
    else:
        print ("""unexpected input, try again""") 
        input(prompt= '<Press enter key to continue>\n')
        outside()
        
def in_house(): #inside the mansion, allways have the option to come back to 
    #this room. Scene 2
    doors = input(prompt="""you have steped into the house, there is a long 
    hallway, yo walk all the way to the end and finally reach 3 closed doors. 
    so what door will you choose?
    1. door 1
    2. door 2
    3. door 3
    (choose 1,2 or 3)\n""")
    print ("********************************")
    try:
        doors = int(doors)
        if doors== 1:
            door_1()
        elif doors==2:
            door_2()
        elif doors ==3:
            door_3()   
        else:
            print ("""unexpected input, try again""")
            in_house()
    except:
        if "one" in doors:
            door_1()
        elif "two" in doors:
            door_2()
        elif "three" in doors:
            door_3()
        else:
            print ("""unexpected input, try again""")
            in_house()

def door_1():
    des_3 = input(prompt="""you go into the dark room, in fact is pitch black at this point 
     you can either:
     1. go in  
     2. decide to go back.
     (choose 1 or 2)\n""") 
    print("*********************************************")
          
    if "go" in des_3: #if statement to go in or return
        madame = input (prompt = """you se a woman in a glas ball.
        'thats weird' you think to yourself, you are intrigued an come close 
        to her. you read a plaque with her name 'madame Leota'. you get freaked 
        out. you can either 
        1. ask her for a fortune.
        2. attack her./n""")
        print("*****************************************")
          
        x = 5
        if "ask" in madame:
            name = input(prompt= "hello what is your name?\n")
            print ("****************************")
            number = random.randint(1,10) # random number
              #create a loop for a riddle
            print (f""" well {name}, to get what you seek you have 
            to guess a number from 1 to 10, you have 5 chances.""")
            
            while x > 0:
                usr_ansr= input (prompt = "/n")
                  # converting choice for numerical comparison
                usr_ansr = int(usr_ansr)
              # conditional statement based on user input
                if usr_ansr == number:
                    print ("""well well well, you are correct, I shall give you what you
                      came for. You are free of the mansion""")
                    break

                elif usr_ansr != number:
                    x -= 1
                    if x>1:
                        print (f"incorrect, you have {x} guesses")
                    elif x == 0:
                        print (f"""sorry you are out of chances, the number was {number}, start 
                               the room again""")
                        door_1()
                    elif x== 1:
                        print (f"""fine I feel bad for you, ill tell you the answer is {number}""")
                    else:
                        print ("error in incorrect guess")
           # setting a different error message for inner and outer loops

                else:
                    print("unexpected error in while loop")
                input(prompt= '<Press enter key to continue>\n')
                print ("""you have won! you are now rich. good bye""") #printing the winning statement

          
        elif "attack" in madame:
            print ("""oh no! that was a mistake, now you have died a super 
            natural death""")
            input(prompt= '<Press enter key to continue>\n')
            fail()
            
        elif madame=="1":
            name = input(prompt= "hello what is your name?\n")
            print("********************************************")
          
            x = 5
            number = random.randint(1,10) # random number
            #create a loop for a riddle
            print (f""" well {name}, to get what you seek you have 
            to guess a number from 1 to 10, you have 5 chances.""")
            while x > 0:
                usr_ansr= input ()

                # converting choice for numerical comparison
                usr_ansr = int(usr_ansr)

                # conditional statement based on user input
                if usr_ansr == number:
                    print ("you win")
                    break

                elif usr_ansr != number:
                    x -= 1

                    if x>1:
                        print (f"incorrect, you have {x} guesses")
                    elif x == 0:
                        print (f"""sorry you are out of chances, the number was {number}, start 
                               the room again\n""")
                        door_1()

                    elif x== 1:
                        print (f"""fine I feel bad for you, ill tell you the answer is {number}\n""")
                    else:
                        print ("error in incorrect guess\n")
        
                # setting a different error message for inner and outer loops
                else:
                    print("unexpected error in while loop")

            print ("""well well well, you are correct, I shall give you what you
                   came for. You are free of the mansion""")
            input(prompt= '<Press enter key to continue>\n')
            print ("""you have won! you are now rich. good bye""")
            
        elif madame =="2":
            print ("""oh no! that was a mistake, now you have died a super- 
            natural death""")
            input(prompt= '<Press enter key to continue>\n')
            fail()
        else:
            print ("unexpected input try again")
            door_1()
    elif "go back" in des_3:
        in_house()
    elif des_3=="1":
        madame = input (prompt = """you se a woman in a glas ball.
        'thats weird' you think to yourself, you are intrigued an come close 
        to her. you read a plaque with her name 'madame Leota'. you get freaked 
        out. you can either 
        1. ask her for a fortune.
        2. atack her.\n""")
        print("***********************************************")
          
        if "ask" in madame:
            name = input(prompt= "hello what is your name?\n")
            x = 5
            number = random.randint(1,10) # random number
            #create a loop for a riddle
            print (f""" well {name}, to get what you seek you have 
            to guess a number from 1 to 10, you have 5 chances.""")
            while x > 0:
                usr_ansr= input ()

                # converting choice for numerical comparison
                usr_ansr = int(usr_ansr)

                # conditional statement based on user input
                if usr_ansr == number:
                    print ("you win")
                    break

                elif usr_ansr != number:
                    x -= 1

                    if x>1:
                        print (f"incorrect, you have {x} guesses")
                    elif x == 0:
                        print (f"""sorry you are out of chances, the number was {number}, start 
                               the room again\n""")
                        door_1()

                    elif x== 1:
                        print (f"""fine I feel bad for you, ill tell you the answer is {number}\n""")
                    else:
                        print ("error in incorrect guess\n")
        
    # setting a different error message for inner and outer loops
                else:
                    print("unexpected error in loop")


            print ("""well well well, you are correct, I shall give you what you
                   came for. You are free of the mansion.""")
            input(prompt= '<Press enter key to continue>\n')
            print ("""you have won! you are now rich. good bye.""")
            
        elif "atack" in madame:
            print ("""oh no! that was a mistake, now you have died a super-natural 
            death""")
            input(prompt= '<Press enter key to continue>\n')
            fail()
            
        elif madame=="1":
            name = input(prompt= "hello what is your name?\n")
            print ("************************************************")
            x = 5
            number = random.randint(1,10) # random number
            #create a loop for a riddle
            print (f""" well {name}, to get what you seek you have 
            to guess a number from 1 to 10, you have 5 chances.""")
            while x > 0:
                usr_ansr= input ()

                # converting choice for numerical comparison
                usr_ansr = int(usr_ansr)

                # conditional statement based on user input
                if usr_ansr == number:
                    print ("you win")
                    break

                elif usr_ansr != number:
                    x -= 1

                    if x>1:
                        print (f"incorrect, you have {x} guesses")
                    elif x == 0:
                        print (f"""sorry you are out of chances, the number was {number}, start 
                               the room again""")
                        door_1()

                    elif x== 1:
                        print (f"""fine I feel bad for you, ill tell you the answer is {number}""")
                    else:
                        print ("error in incorrect guess")
        
    # setting a different error message for inner and outer loops
                else:
                    print("unexpected error in loop.")

            print ("""well well well, you are correct, I shall give you what you
                   came for. You are free of the mansion.""")
            input(prompt= '<Press enter key to continue>\n')
            print ("""you have won! you are now rich. good bye.""")
            
        elif madame=="2":
            print ("""oh no! that was a mistake, now you have died a super-natural
            death.""")
            input(prompt= '<Press enter key to continue>\n')
            fail()
        else:
            print ("unexpected input try again.")
            door_1()
    
    elif des_3 =="2":
        in_house()
    else:
        print ("""unexpected input try again.""")
        door_1()
def door_2():
    des_4= input(prompt ="""you find yoursef in very dim kitchen, it smells soo good.
            what will you do?
            1. go in.
            2. leave? 
            (answer 1 or 2)\n""")
    print ("**********************************************")
    if "leave"in des_4:
        in_house()
    elif "go"in des_4:
        
        kitchen = input (prompt ="""you have entered the kitchen, you se a table
        full of incredible treats, what you do next?
                1. turn on lights
                2. eat the treats
                (pick 1 or 2)\n""")
        if "turn" in kitchen:
            print( """oh! you realize the treats have poison in them, you have 
            to leave the kitchen. you return to the main corridor""")
            in_house()
        elif float(kitchen)==1:
            print( """oh! you realize the treats have poison in them, you have 
            to leave the kitchen. you return to the main corridor.""")
            in_house()
        elif "eat" in kitchen:
            print ("""really bad decision! the food is poisoned! you fail.""")
            fail()
        elif float(kitchen)==2:
            print ("""really bad decision! the food is poisoned! you fail.""")
            fail()
        else:
            print ("""Unexpected input, try again.""")
            door_2()
    elif float(des_4)==1:
        kitchen = input (prompt ="""you have entered the kitchen, you se a table
        full of incredible treats, what you do next?
                1. turn on lights.
                2. eat the treats.
                (pick 1 or 2)\n""")
        print ("************************************************")
        
        if "turn" in kitchen:
            print ("""oh! you realize the treats have poison in them, you have 
            to leave the kitchen. you return to the main corridor.""")
            in_house()
        elif float(kitchen)==1:
            print ("""oh! you realize the treats have poison in them, you have 
            to leave the kitchen. you return to the main corridor.""")
            in_house()
        elif "eat" in kitchen:
            print ("""really bad decision! the food is poisoned! you fail.""")
            fail()
        elif float(kitchen)==2:
            print ("""really bad desicion! the food is poisoned! you fail.""")
            fail()
        else:
            print ("""Unexpected input, try again.""")
            door_2()
    else:
        print ("""Unexpected input, try again.""")
        door_2()


def door_3():
    des_5 = input (prompt = """you find yoursef outside in what looks like a 
    graveyard, do you want to walk further? 
    1. walk further. 
    2. return.
    (choose 1 or 2)\n""")
    print("************************************************")
    if "walk" in des_5:
        busts = input (prompt= """you see what looks like a barbershop quartet but
                       made out of stone, like busts, do you... 
                       1. talk to them.
                       2. leave.
                       (answer 1 or 2)\n""")
        if "talk" in busts:
            print ("""the busts burst into song letting you know that time in the 
                   mansion is not what it feels like, and you have actually been missing for a week.
                   in a burst of panic, you leave the mansion without the money. 
                   you lost.""")

            
            fail()
        elif "leave" in busts: 
            door_3()
            
        elif busts=="1":
            print("""the busts burst into song letting you know that time in the 
                   mansion is not what it feels like, and you have actually been missing for a week.
                   in a burst of panic, you leave the mansion without the money. 
                   you lost.""")

            fail()
        elif busts=="2":
            door_3()
            
        else:
            print("""unexepected input, please try again""")
            door_3()
            
    elif "return" in des_5:
        in_house()
        
    elif des_5 == "1":
        
        busts = input (prompt= """you see what looks like a barbershop quartet but
                       made out of stone, like busts, do you... 
                       1. talk to them.
                       2. leave
                       (answer 1 or 2)\n""")
        print ("*******************************************")
        if "talk" in busts:
            print ("""the busts burst into song letting you know that time in the 
                   mansion is not what it feels like, and you have actually been missing for a week.
                   in a burst of panic, you leave the mansion without the money. 
                   you lost.""")
            
            fail()
        elif "leave" in busts: 
            door_3()
            
        elif busts=="1":
            print ("""the busts burst into song letting you know that time in the 
                   mansion is not what it feels like, and you have actually been missing for a week.
                   in a burst of panic, you leave the mansion without the money. 
                   you lost.""")

            fail()
        elif busts=="2":
            door_3()
            
        else:
            print("""unexepected input, please try again""")
            door_3()
            


print("""Hello player! and welcome to the Haunted Mansion Adventure. 
It was a rainy Tuesday, and you receive a phone call telling you that your great-
aunt (who you have never met) has passed away. They tell you, since you are her
only living relative you get all the money. But your great-aunt was a particular
woman who lived in a haunted house and kept all her money in cash. So, you now 
have to survive the haunted mansion to get the very needed money""")


input(prompt= '<Press enter key to continue>\n')
intro()
# Out:
# Hello player! and welcome to the Haunted Mansion Adventure.
# It was a rainy Tuesday, and you receive a phone call telling you that your great-
# aunt (who you have never met) has passed away. They tell you, since you are her
# only living relative you get all the money. But your great-aunt was a particular
# woman who lived in a haunted house and kept all her money in cash. So, you now
# have to survive the haunted mansion to get the very needed money
# <Press enter key to continue>
# 1
# you stand ouside of the mansion,
#     chills running down your spine.
#     you wander, what to do next?
#     1. knock on the very creepy door.
#     2. you try doorknob.
#     3. you turn arround and leave.
#     (answer 1, 2 or 3)
#
#  1
# *****************************************
# the door opens, what shall you do next?
#         1. go in
#         2. turn arround
#         (answer 1 or 2)1
# ***********************************
# You slowly make your way into the house.
# ...
